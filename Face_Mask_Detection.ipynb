# %% [markdown]
# <a href="https://colab.research.google.com/github/jp-singaraju/Fask-Mask-Detection/blob/master/Face_Mask_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

dataLx = os.chdir('/content/Larxel Photos')
counter = 0

for item in os.listdir(dataLx):
  if counter > 5:
    break
  img = mpimg.imread(item)
  imgplot = plt.imshow(img)
  counter += 1
